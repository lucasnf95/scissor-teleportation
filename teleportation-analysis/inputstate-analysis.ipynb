       1.33580801e-07, 8.69860478e-08, 5.66441621e-08, 3.68859280e-08,
       2.40196277e-08, 1.56412634e-08, 1.01853835e-08, 6.63258683e-09,
       4.31905268e-09, 2.81250990e-09, 1.83146919e-09, 1.19262847e-09,
       7.76623864e-10, 5.05727173e-10, 3.29322836e-10, 2.14450668e-10,
       1.39647434e-10, 9.09365595e-11, 5.92166829e-11, 3.85611195e-11,
       2.51104902e-11, 1.63516186e-11, 1.06479574e-11, 6.93380883e-12,
       4.51520446e-12, 2.94024133e-12, 1.91464621e-12, 1.24679225e-12,
       8.11894596e-13, 5.28695006e-13, 3.44279185e-13, 2.24190045e-13,
       1.45989587e-13, 9.50664854e-14, 6.19060360e-14, 4.03123906e-14,
       2.62508947e-14, 1.70942349e-14, 1.11315393e-14, 7.24871097e-15,
       4.72026456e-15, 3.07377375e-15, 2.00160075e-15, 1.30341590e-15,
       8.48767165e-16, 5.52705935e-16, 3.59914783e-16, 2.34371739e-16,
       1.52619772e-16, 9.93839738e-17, 6.47175272e-17, 4.21431965e-17,
       2.74430913e-17, 1.78705775e-17, 1.16370834e-17, 7.57791453e-18,
       4.93463756e-18, 3.21337061e-18, 2.09250438e-18, 1.36261113e-18,
       8.87314319e-19, 5.77807330e-19, 3.76260480e-19, 2.45015840e-19,
       1.59551069e-19, 1.03897543e-19, 6.76567037e-20, 4.40571492e-20,
       2.86894320e-20, 1.86821781e-20, 1.21655869e-20, 7.92206902e-21,
       5.15874641e-21, 3.35930732e-21, 2.18753643e-21, 1.42449475e-21,
       9.27612109e-22, 6.04048718e-22, 3.93348523e-22, 2.56143348e-22,
       1.66797155e-22, 1.08616098e-22, 7.07293642e-23, 4.60580250e-23,
       2.99923758e-23, 1.95306378e-23, 1.27180926e-23, 8.28185345e-24,
       5.39303326e-24, 3.51187182e-24, 2.28688441e-24, 1.48918883e-24,
       9.69740042e-25, 6.31481870e-25, 4.11212629e-25, 2.67776217e-25,
       1.74372325e-25, 1.13548948e-25, 7.39415710e-26, 4.81497716e-26,
       3.13544934e-26, 2.04176308e-26, 1.32956907e-26, 8.65797766e-27,
       5.63796036e-27, 3.67136510e-27, 2.39074432e-27, 1.55682103e-27])

# %%
input_folder = r"C:\\Users\\lunfa\\Documents\\PhD\\Python\\teleportation\\files\\input state\\"

dates = []
for file in os.listdir(input_folder):
    dates.append(file + '\\')

voltages = [None for date in dates]
extra = [None for date in dates]
folders = [None for date in dates]
input_files = [None for date in dates]
for d, date in enumerate(dates):
    files = os.listdir(os.path.join(input_folder + date))
    voltages[d] = [file + '\\' for file in files if '.txt' not in file]
    
for d in range(len(dates)):
    extra[d] = ['' for voltage in voltages[d]]
    folders[d] = ['' for voltage in voltages[d]]
    input_files[d] = [None for voltage in voltages[d]]
for d in range(len(dates)):
    for v, voltage in enumerate(voltages[d]):
        files = os.listdir(os.path.join(input_folder + dates[d] + voltage))
        extra[d][v] = [file + '\\' for file in files if '.trc' not in file]
        if extra[d][v] == []:
            extra[d][v] = ''

for d in range(len(dates)):
    for v in range(len(voltages[d])):
        folders[d][v] = ['' for e in extra[d][v]]
        input_files[d][v] = [None for e in extra[d][v]]
for d in range(len(dates)):
    for v in range(len(voltages[d])):
        if len(extra[d][v]) == 0:
            folders[d][v].append(os.path.join(input_folder + dates[d] + voltages[d][v] + extra[d][v]))
            input_files[d][v].append(None)
        for e in range(len(extra[d][v])):
            folders[d][v][e] = os.path.join(input_folder + dates[d] + voltages[d][v] + extra[d][v][e])

# %%
for d in range(len(folders)):
    for v in range(len(folders[d])):
        for e in range(len(folders[d][v])):
            print(folders[d][v][e])
            input_files[d][v][e] = inputstate.inputstate(folders[d][v][e], dimension, mf, input_plot = False)
# Out:
# C:\\Users\\lunfa\\Documents\\PhD\\Python\\teleportation\\files\\input state\\20240222\001\1\
# CALCULATING INPUT STATE PARAMETERS
# Clearance at 10.0 MHz is 14.59 dB
# 0.5337 vacuum files and 0.4663 input files
# 0.4985 vacuum files and 0.5015 input files
# Block 0 Input |\alpha| = 0.1290450025526906
# Block 1 Input |\alpha| = 0.08156336001895069
# Block 2 Input |\alpha| = 0.07369650489734102
# Block 3 Input |\alpha| = 0.1698997329305048
# Block 4 Input |\alpha| = 0.04156256617608602
# Block 5 Input |\alpha| = 0.12395588557750385
# Block 6 Input |\alpha| = 0.10811832498983434
# Block 7 Input |\alpha| = 0.13545514897896382
# Block 8 Input |\alpha| = 0.1606423420750082
# Block 9 Input |\alpha| = 0.1240686265392238
# Input |\alpha| averaged through all blocks: 0.11 (0.04)
# Input angle averaged through all blocks: 88.41 (17.43)°
# Input |alpha| = 0.11
# Relay theta = 90.00°
# Input state theta = 88.41°
# PLOTS FOR INPUT STATE
# ...

# %%
for d, date in enumerate(dates):
    for v in range(len(input_files[d])):
        for f, fv in enumerate(input_files[d][v]):
            print(date, fv.clearance)
# Out:
# 20240222\ 14.58945597810646
# 20240222\ 14.783740796743892
# 20240222\ 14.863636770917626
# 20240222\ 14.825519179018428
# 20240222\ 14.664916650166688
# 20240222\ 14.818152844430557
# 20240226\ 15.769181246179379
# 20240226\ 15.784507441576157
# 20240226\ 15.751460606767552
# 20240227\ 14.110609124187704
# 20240227\ 14.078984408040562
# 20240313\ 14.605712774945694
# 20240313\ 14.652794151252937
# 20240313\ 14.693676470622911
# 20240313\ 14.726458538099624
# 20240313\ 14.65032717425223

# %%
possible_voltages = ['001', '002', '003', '004', '005']

files_voltage = [[] for v in possible_voltages]
files_alpha = [[] for v in possible_voltages]
files_theta = [[] for v in possible_voltages]
amount = np.zeros(len(possible_voltages))
day = [[] for v in possible_voltages]
for d, date in enumerate(dates):
    # Ignoring data with bad clearance
    if date == '20240312\\':
        pass
    else:
        for v, voltage in enumerate(voltages[d]):
            for p, pv in enumerate(possible_voltages):
                if pv in voltage:
                    files_voltage[p].append(input_files[d][v])
                    for f in range(len(input_files[d][v])):
                        files_alpha[p].append(input_files[d][v][f].input_alpha)
                        files_theta[p].append(input_files[d][v][f].input_angle)
                        amount[p] += 1
                        day[p].append(date)

# %%
size = (10, 8)
for p, pv in enumerate(possible_voltages):
    x_ticks = [d[:-1] for d in day[p]]
    
    plt.figure(figsize = size)
    plt.grid()
    plt.plot(np.arange(amount[p]), files_alpha[p], 'o', color = 'orange')
    plt.xticks(np.arange(amount[p]), x_ticks)
    plt.xlabel('Date')
    plt.ylabel('$|\\alpha|$ (snu)')
    plt.title('Amplitude of input state for voltage 0.' + pv + ' V')
    
    plt.figure(figsize = size)
    plt.grid()
    plt.plot(np.arange(amount[p]), files_theta[p], 'o', color = 'm')
    plt.xticks(np.arange(amount[p]), x_ticks)
    plt.xlabel('Date')
    plt.ylabel('$\\theta$ (°)')
    plt.title('Angle of input state for voltage 0.' + pv + ' V')

# %%
alpha_day = {date: [] for date in dates}
dict_alpha_std = {date: [] for date in dates}
theta_day = {date: [] for date in dates}
dict_theta_std = {date: [] for date in dates}
for d, date in enumerate(dates):
    for v, volt in enumerate(voltages[d]):
        alphas = [None for f in input_files[d][v]]
        thetas = [None for f in input_files[d][v]]
        for f, fv in enumerate(input_files[d][v]):
            alphas[f] = fv.input_alpha
            thetas[f] = fv.input_angle
        mean_alpha = np.mean(alphas)
        std_alpha = np.std(alphas)
        mean_theta = np.mean(thetas)
        std_theta = np.std(thetas)
        alpha_day[date].append(mean_alpha)
        theta_day[date].append(mean_theta)
        dict_alpha_std[date].append(std_alpha)
        dict_theta_std[date].append(std_theta)

# %%
for d, date in enumerate(dates):
    x_ticks = ['0.' + v[:-1] for v in voltages[d]]
    
    plt.figure(figsize = size)
    plt.errorbar(np.arange(len(voltages[d])), alpha_day[date], yerr = dict_alpha_std[date], fmt = 'o', color = 'orange')
    plt.xticks(np.arange(len(voltages[d])), x_ticks)
    plt.grid()
    plt.xlabel('Voltage (V)')
    plt.ylabel('$|\\alpha|$ (snu)')
    plt.title('Input state calibration on day ' + date[:-1])
    
    plt.figure(figsize = size)
    plt.errorbar(np.arange(len(voltages[d])), theta_day[date], yerr = dict_theta_std[date], fmt = 'o', color = 'm')
    plt.xticks(np.arange(len(voltages[d])), x_ticks)
    plt.grid()
    plt.xlabel('Voltage (V)')
    plt.ylabel('$\\theta$ (°)')
    plt.title('Angle of input state on day ' + date[:-1])

# %%
st_alpha_volt = np.zeros((2, len(possible_voltages)))
st_theta_volt = np.zeros((2, len(possible_voltages)))
for v in range(len(possible_voltages)):
    st_alpha_volt[0][v] = np.mean(files_alpha[v])
    st_alpha_volt[1][v] = np.std(files_alpha[v])
    st_theta_volt[0][v] = np.mean(files_theta[v])
    st_theta_volt[1][v] = np.std(files_theta[v])
    
plt.figure(figsize = size)
plt.errorbar(np.arange(len(possible_voltages)), st_alpha_volt[0][:], yerr = st_alpha_volt[1][:], fmt = 'o', color = 'orange')
plt.xticks(np.arange(len(possible_voltages)), possible_voltages)
plt.grid()
plt.xlabel('Voltage')
plt.ylabel('|\\alpha|')
plt.title('Input state calibration')

plt.figure(figsize = size)
plt.errorbar(np.arange(len(possible_voltages)), st_theta_volt[0][:], yerr = st_theta_volt[1][:], fmt = 'o', color = 'm')
plt.xticks(np.arange(len(possible_voltages)), possible_voltages)
plt.grid()
plt.xlabel('Voltage')
plt.ylabel('\\theta')
plt.title('Input state calibration')
# Out:
# Text(0.5, 1.0, 'Input state calibration')
